# %%
import pandas as pd

# %%
df = pd.read_csv('Original/GMPI2021_publicuse.csv')

# %% [markdown]
# # Standardize country names

# %%
# df.head()
# Out:
#   flav     w_region  cty_lab ccty  ccnum   t       year survey  loa  area_lab  \
# 0  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
# 1  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
# 2  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
# 3  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
# 4  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
#
#   measure                 measure_lab indicator          ind_lab          b  \
# 0      M0                         MPI       NaN              NaN   0.005409
# 1       H             Headcount ratio       NaN              NaN   1.380835
# 2       A                   Intensity       NaN              NaN  39.172628
# 3      hd  Uncensored headcount ratio    d_nutr        Nutrition   5.825295
# 4      hd  Uncensored headcount ratio      d_cm  Child mortality   1.138596
#
#                   se     k   wgts  spec misind_lab
# 0  .0006646200004152  33.0  equal  gmpi        NaN
# 1    .15076397587442  33.0  equal  gmpi        NaN
# 2    .96566740646732  33.0  equal  gmpi        NaN
# 3    .25438270613317   NaN    NaN  gmpi        NaN
# 4    .08131516325524   NaN    NaN  gmpi        NaN

# %%
## Export to pass through country name tool
# df[['cty_lab']].rename(columns={'cty_lab': 'country'}).drop_duplicates().to_csv("Manipulation/MPI countries.csv", index = False)

# %%
country_names_map = pd.read_csv("Manipulation/MPI countries_country_standardized.csv")

# %%
country_names_map.head()
# Out:
#    country Our World In Data Name
# 0  Algeria                Algeria
# 1    Egypt                  Egypt
# 2     Iraq                   Iraq
# 3   Jordan                 Jordan
# 4    Libya                  Libya

# %%
df = pd.merge(df.rename(columns={'cty_lab': 'country'}),country_names_map,how='left', on='country')

# %%
df.head()
# Out:
#   flav     w_region  country ccty  ccnum   t       year survey  loa  area_lab  \
# 0  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
# 1  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
# 2  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
# 3  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
# 4  cme  Arab States  Algeria  DZA     12 NaN  2018-2019   MICS  nat  National
#
#    ...                 measure_lab indicator          ind_lab          b  \
# 0  ...                         MPI       NaN              NaN   0.005409
# 1  ...             Headcount ratio       NaN              NaN   1.380835
# 2  ...                   Intensity       NaN              NaN  39.172628
# 3  ...  Uncensored headcount ratio    d_nutr        Nutrition   5.825295
# 4  ...  Uncensored headcount ratio      d_cm  Child mortality   1.138596
#
#                   se     k   wgts  spec misind_lab Our World In Data Name
# 0  .0006646200004152  33.0  equal  gmpi        NaN                Algeria
# 1    .15076397587442  33.0  equal  gmpi        NaN                Algeria
# 2    .96566740646732  33.0  equal  gmpi        NaN                Algeria
# 3    .25438270613317   NaN    NaN  gmpi        NaN                Algeria
# 4    .08131516325524   NaN    NaN  gmpi        NaN                Algeria
#
# [5 rows x 21 columns]

# %%
df = df.drop(columns='country')
df = df.rename(columns={'Our World In Data Name': 'country'})

# %% [markdown]
# # Separate cme from hot
# Due to changing data coverage across surveys, OPHI produce two sets of estiamtes: point estimates for single years (`flav = cme`) and estiamtes intended to track change over time (`flav = hot`).
#
# Let's separate these out.
